# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as s

# %%
path=r'Desktop/'
dataset=pd.read_csv(path+'parkinson1.csv')
dataset.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer   ...    \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374   ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134   ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233   ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492   ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425   ...
#
#    Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1   spread2  \
# ...

# %%
col=dataset.columns
print(col)
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1',
#        'spread2', 'D2', 'PPE', 'status'],
#       dtype='object')

# %%
y=dataset.status

# %%
list=['name','status']
X=dataset.drop(list,axis = 1)

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# 5        120.552       131.162       113.787         0.00968
# 6        120.267       137.244       114.820         0.00333
# 7        107.332       113.840       104.315         0.00290
# 8         95.730       132.068        91.754         0.00551
# 9         95.056       120.103        91.226         0.00532
# 10        88.333       112.240        84.072         0.00505
# 11        91.904       115.871        86.292         0.00540
# 12       136.926       159.866       131.276         0.00293
# 13       139.173       179.139        76.556         0.00390
# ...

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(X_new.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
X_new.shape
# Out:
# (195, 14)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
#importing and fitting our rando forets classifier onto our training set
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV

# %%
from sklearn.preprocessing import StandardScaler
sc1=StandardScaler()

X_train=sc1.fit_transform(X_train)
X_test=sc1.transform(X_test)

# %%
clf_rf_4 = RandomForestClassifier(n_estimators = 680,criterion='entropy',random_state=0)
rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')   #5-fold cross-validation
rfecv = rfecv.fit(X_train, y_train)
rfecv.grid_scores_
# Out:
# array([0.81604269, 0.84292282, 0.85600985, 0.88408867, 0.89052545,
#        0.87719212, 0.89075534, 0.8636289 , 0.87029557, 0.87029557,
#        0.87719212, 0.88385878, 0.88385878, 0.87719212, 0.88385878,
#        0.88385878, 0.88385878, 0.87052545, 0.87719212, 0.87052545,
#        0.87052545, 0.87719212])

# %%
print('Optimal number of features :', rfecv.n_features_)
rfecv.predict_proba()

print('Best features :', X_train.columns[rfecv.support_])
# Out:
# Optimal number of features : 7
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-221-44d4fef9b961> in <module>()
#       2 rfecv.predict_proba
#       3
# ----> 4 print('Best features :', X_train.columns[rfecv.support_])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score of number of selected features")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
clr_rf_4 = clf_rf_4.fit(X_train,y_train)
#predicting our results
y_pred = clr_rf_4.predict(X_test)

# %%
ac_2 = accuracy_score(y_test,clf_rf_4.predict(X_test))
print('Accuracy is: ',ac_2)
# Out:
# Accuracy is:  0.9387755102040817

# %%
cm_2 = confusion_matrix(y_test,clf_rf_4.predict(X_test))

# %%
cm_2
# Out:
# array([[10,  1],
#        [ 2, 36]], dtype=int64)

# %%
from sklearn import model_selection, preprocessing
import xgboost as xgb
xgb_params = {
    'eta': 0.05,
    'max_depth': 8,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
#training the model to get feature importance
dtrain = xgb.DMatrix(X_train, y_train, feature_names=X_train.columns.values)
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)
featureImportance = model.get_fscore()
# Out:
# C:\Users\khwaja wisal\Anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:25:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
features = pd.DataFrame()
features['features'] = featureImportance.keys()
features['importance'] = featureImportance.values()
features.sort_values(by=['importance'],ascending=False,inplace=True)
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
plt.xticks(rotation=90)
sns.barplot(data=features.head(15),x="importance",y="features",ax=ax,orient="h", color = "#34495e")

# %%
classifier = RandomForestClassifier(n_estimators = 1500,criterion='entropy', random_state = 42)
            
            
#second method for feature selection


classifier = classifier.fit(X_train,y_train)
ypred=classifier.predict(X_test)
importances = classifier.feature_importances_
std = np.std([tree.feature_importances_ for tree in classifier.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
#plotting the graph
plt.figure(1, figsize=(14, 13))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices],rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 21 (0.103749)
# 2. feature 18 (0.100453)
# 3. feature 19 (0.077373)
# 4. feature 0 (0.077208)
# 5. feature 12 (0.070349)
# 6. feature 11 (0.052410)
# 7. feature 1 (0.049594)
# 8. feature 8 (0.044932)
# 9. feature 2 (0.043106)
# 10. feature 20 (0.042455)
# 11. feature 10 (0.038140)
# 12. feature 13 (0.035453)
# 13. feature 17 (0.034125)
# 14. feature 16 (0.032764)
# 15. feature 9 (0.031554)
# 16. feature 14 (0.028029)
# 17. feature 15 (0.027240)
# 18. feature 7 (0.025914)
# 19. feature 5 (0.023496)
# 20. feature 4 (0.023020)
# 21. feature 3 (0.019708)
# 22. feature 6 (0.018927)

# %%
list=['name','MDVP:PPQ','MDVP:Jitter(%)','MDVP:Jitter(Abs)','MDVP:RAP','Jitter:DDP','HNR','NHR','MDVP:Shimmer(dB)','RPDE']
X_new=dataset.drop(list,axis=1)
Y_new=dataset.status
from sklearn.cross_validation import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_new,Y_new, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train1.shape
# Out:
# (136, 14)

# %%
X_train1=sc.fit_transform(X_train1)
X_test1=sc.transform(X_test1)
X_train1.shape
# Out:
# (136, 14)

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense

# %%
classifier=Sequential()
classifier.add(Dense(12, input_dim=14,activation='relu',kernel_initializer='glorot_uniform'))

classifier.add(Dense(56,activation='relu',kernel_initializer='glorot_uniform'))
classifier.add(Dense(24,activation='relu',kernel_initializer='glorot_uniform'))
#classifier.add(Dense(24,activation='relu',kernel_initializer='glorot_uniform'))
classifier.add(Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform'))
classifier.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.fit(X_train1,y_train1,batch_size=30,epochs=20)
# Out:
# Epoch 1/20
# 136/136 [==============================] - 2s 15ms/step - loss: 0.5271 - acc: 0.9118
# Epoch 2/20
# 136/136 [==============================] - 0s 265us/step - loss: 0.4334 - acc: 0.9265
# Epoch 3/20
# 136/136 [==============================] - 0s 236us/step - loss: 0.3496 - acc: 0.9265
# Epoch 4/20
# 136/136 [==============================] - 0s 205us/step - loss: 0.2705 - acc: 0.9412
# Epoch 5/20
# 136/136 [==============================] - 0s 235us/step - loss: 0.2044 - acc: 0.9559
# Epoch 6/20
# 136/136 [==============================] - 0s 235us/step - loss: 0.1478 - acc: 0.9779
# Epoch 7/20
# 136/136 [==============================] - 0s 206us/step - loss: 0.1044 - acc: 0.9926
# Epoch 8/20
# 136/136 [==============================] - 0s 206us/step - loss: 0.0710 - acc: 1.0000
# Epoch 9/20
# 136/136 [==============================] - 0s 206us/step - loss: 0.0471 - acc: 1.0000
# Epoch 10/20
# ...

# %%
scores = classifier.evaluate(X_test1,y_test1)
print("\n%s: %.2f%%" % (classifier.metrics_names[1], scores[1]*100))
y_pred= classifier.predict(X_test1, verbose=1)
# Out:
# 59/59 [==============================] - 1s 13ms/step
#
# acc: 100.00%
# 59/59 [==============================] - 0s 7ms/step

# %% [raw]
# y_pred

# %%
X_test.shape
# Out:
# (49, 22)
