# %%
from keras.models import Sequential
import pandas
from pandas import read_csv
from pandas import set_option
from pandas import scatter_matrix
from keras.layers import Dense
import numpy
from keras.utils import np_utils
from keras.utils import np_utils
from sklearn.metrics import matthews_corrcoef
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# fix random seed for reproducibility
#dataframe = pandas.read_csv("parkinsons.csv", delim_whitespace=None, header=None)
dataframe = pandas.read_csv("parkinsons.csv" , encoding ='ISO-8859-1')
dataframe=dataframe.drop('name', axis=1)
dataset = dataframe.values
numpy.random.shuffle(dataset)
train, test = train_test_split(dataset, test_size = 0.2)
numpy.random.shuffle(train)
numpy.random.shuffle(test)
x_train = train[:,0:23]
y_train = train[:,16]
y_test=test[:,16]
x_test=test[:,0:23]
print(x_train.shape)
print(y_train.shape)

# encode class values as integers
#encoder = LabelEncoder()
#encoder.fit(y_train)
#encoded_ytrain = encoder.transform(y_train)
# convert integers to dummy variables (i.e. one hot encoded)
#dtrain_y = np_utils.to_categorical(encoded_ytrain)

#encoder.fit(y_test)
#encoded_ytest = encoder.transform(y_test)
# convert integers to dummy variables (i.e. one hot encoded)
#dtest_y = np_utils.to_categorical(encoded_ytest)

print(x_train.shape)
print(x_test.shape)

dtest_y = np_utils.to_categorical(y_test)
dtrain_y= np_utils.to_categorical(y_train)
print(dtrain_y.shape)
print(dtest_y.shape )



#dtrain_y = keras.utils.to_categorical(y_train)
#y_test = keras.utils.to_categorical(np.random.randint(10, size=(100, 1)), num_classes=10)
#dtest_y = np_utils.to_categorical(y_test)

# split into input (X) and output (Y) variables
#print(dataset.shape)
#X = dataset[:,0:8]
#Y = dataset[:,8]
#Y = np_utils.to_categorical(Y)
#print(x_train.shape)
#print(y_train.shape)
#print(x_test)
#print(y_test)
# create model
model = Sequential()
model.add(Dense(12, input_dim=23,activation='relu'))
model.add(Dense(56, activation='relu'))
#model.add(Dense(12, activation='relu'))
#model.add(Dense(12, activation='relu'))
#model.add(Dense(40, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(x_train,y_train, epochs=500, batch_size=20)
# evaluate the model
#scores = model.evaluate(x_test,y_test)
#print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#y_pred= model.predict(x_test, verbose=1)
# Out:
# Using TensorFlow backend.
# (156, 23)
# (156,)
# (156, 23)
# (39, 23)
# (156, 2)
# (39, 2)
# Epoch 1/500
# 156/156 [==============================] - 0s - loss: 0.9688 - acc: 0.6026
# Epoch 2/500
# 156/156 [==============================] - 0s - loss: 0.8177 - acc: 0.7244
# Epoch 3/500
# 156/156 [==============================] - 0s - loss: 0.7628 - acc: 0.7051
# Epoch 4/500
# 156/156 [==============================] - 0s - loss: 0.7092 - acc: 0.7051
# Epoch 5/500
# 156/156 [==============================] - 0s - loss: 0.7036 - acc: 0.7500
# Epoch 6/500
# 156/156 [==============================] - 0s - loss: 0.6934 - acc: 0.6603
# Epoch 7/500
# 156/156 [==============================] - 0s - loss: 0.6428 - acc: 0.7564
# Epoch 8/500
# 156/156 [==============================] - 0s - loss: 0.6317 - acc: 0.7564
# Epoch 9/500
# 156/156 [==============================] - 0s - loss: 0.6126 - acc: 0.7564
# Epoch 10/500
# ...

# %%
df=pd.read_csv('zsfirst.csv')

# %%
import pandas as pd

# %%
p=df['is_goal']
import numpy as np

# %%
p=np.around(p,decimals=1)

# %%
df['is_goal']=p

# %%
df.to_csv('done.csv',index=False)
